# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('../kicksharing_drop.csv',index_col=0)

# %%
df['local_book_start_dttm'] = pd.to_datetime(df['local_book_start_dttm'])

# %%
df['local_hour_start'] = df['local_book_start_dttm'].dt.hour

# %%
hour = df.groupby('local_hour_start').agg(count=('local_hour_start', 'count')).reset_index()
hour.columns = ['hour', 'count']

# %%
sns.barplot(x='hour', y='count', data=hour)
# Out:
# <Axes: xlabel='hour', ylabel='count'>

# %%
fives = df[df['local_hour_start'] == 5]

fives
# Out:
#          order_rk    party_rk gender_cd  age education_level_cd  \
# 7       265062394   866880584         M   38                NaN
# 15      267646217   397325703         M   32                NaN
# 23      267134981  1054751962         M   27                NaN
# 34      267392172   215688302         M   35                GRD
# 88      262576877   684382319         M   32                NaN
# ...           ...         ...       ...  ...                ...
# 396613  253403050   601319921         M   31                GRD
# 396635  266073537  1017524468         M   24                NaN
# 396653  252635089   123661956         F   33                NaN
# 396663  263091488   206962567         M   47                NaN
# 396696  259978037   792058642         F   26                NaN
#
#        marital_status_cd        lvn_state_nm  minute_cost  activation_cost  \
# 7                    NaN    СВЕРДЛОВСКАЯ ОБЛ         5.99             30.0
# 15                   UNM    СВЕРДЛОВСКАЯ ОБЛ         5.49             30.0
# 23                   NaN              МОСКВА         5.99             50.0
# 34                   MAR              МОСКВА         6.99             50.0
# 88                   UNM  КРАСНОДАРСКИЙ КРАЙ         4.99             35.0
# ...                  ...                 ...          ...              ...
# 396613               UNM              МОСКВА         7.99             50.0
# 396635               NaN   НОВОСИБИРСКАЯ ОБЛ         5.49             30.0
# 396653               NaN              МОСКВА         7.99             50.0
# 396663               NaN      МОСКОВСКАЯ ОБЛ         7.11             50.0
# 396696               MAR     ЧЕЛЯБИНСКАЯ ОБЛ         5.49             30.0
#
#         hold_amount  ...               book_end_dttm  book_time_zone_cd  \
# 7             300.0  ...  2024-08-03 03:18:47.841493                  5
# 15            300.0  ...  2024-08-13 03:40:25.238749                  5
# 23            300.0  ...  2024-08-11 05:54:02.032543                  3
# 34            300.0  ...  2024-08-12 05:31:16.432683                  3
# 88            300.0  ...  2024-07-25 05:57:18.197249                  3
# ...             ...  ...                         ...                ...
# 396613        300.0  ...  2024-06-20 05:13:26.939468                  3
# 396635        300.0  ...  2024-08-07 02:03:43.541276                  7
# 396653        300.0  ...  2024-06-17 05:33:55.591071                  3
# 396663        300.0  ...  2024-07-27 05:37:09.724260                  3
# 396696        300.0  ...  2024-07-15 03:23:18.179032                  5
#
#             local_book_start_dttm nominal_price_rub_amt  \
# 7      2024-08-03 05:09:38.493851                 89.90
# 15     2024-08-13 05:38:28.873442                 40.98
# 23     2024-08-11 05:42:28.514890                121.88
# 34     2024-08-12 05:23:56.243404                105.92
# 88     2024-07-25 05:00:07.915984                324.42
# ...                           ...                   ...
# 396613 2024-06-20 05:06:33.781527                105.93
# 396635 2024-08-07 05:57:52.331720                 62.94
# 396653 2024-06-17 05:19:00.755443                169.85
# 396663 2024-07-27 05:31:10.711798                 92.66
# 396696 2024-07-15 05:19:43.409897                 51.96
#
#        loyalty_accrual_rub_amt  loyalty_accrual_bns_amt  \
# 7                        12.99                      NaN
# 15                       12.29                      NaN
# 23                       54.84                      NaN
# 34                       15.59                      NaN
# 88                       32.45                      NaN
# ...                        ...                      ...
# 396613                   10.59                      NaN
# 396635                    6.29                      NaN
# 396653                   16.99                      NaN
# 396663                   28.73                      NaN
# 396696                    7.79                      NaN
#
#                    travel_time  travel_time_h  average_speed  local_hour_start
# 7       0 days 00:09:09.347642       0.152597      15.496732                 5
# 15      0 days 00:01:56.365307       0.032324      14.437500                 5
# 23      0 days 00:11:33.517653       0.192644      19.450777                 5
# 34      0 days 00:07:20.189279       0.122275      19.565574                 5
# 88      0 days 00:57:10.281265       0.952856      18.747114                 5
# ...                        ...            ...            ...               ...
# 396613  0 days 00:06:53.157941       0.114766      14.678261                 5
# 396635  0 days 00:05:51.209556       0.097558      15.408163                 5
# 396653  0 days 00:14:54.835628       0.248565       9.148594                 5
# 396663  0 days 00:05:59.012462       0.099726      22.980000                 5
# 396696  0 days 00:03:34.769135       0.059658      10.200000                 5
#
# [25382 rows x 24 columns]

# %%
none_fives = df[df['local_hour_start'] == 8]
none_fives
# Out:
#          order_rk    party_rk gender_cd  age education_level_cd  \
# 12      349990173   676025738         F   34                GRD
# 56      314902086   862982134         M   45                NaN
# 57      264798748    32477259         M   33                GRD
# 70      255771751  1027453844         M   39                NaN
# 124     260754851   546546919         M   26                UGR
# ...           ...         ...       ...  ...                ...
# 396610  257888628   374643874         F   30                NaN
# 396727  255772876   507877409         M   44                SCH
# 396731  350798361   254177330         M   26                UGR
# 396733  259469771   143279756         M   31                NaN
# 396742  349389313   643856287         M   24                GRD
#
#        marital_status_cd      lvn_state_nm  minute_cost  activation_cost  \
# 12                   UNM  СВЕРДЛОВСКАЯ ОБЛ         5.99             30.0
# 56                   NaN     САМАРСКАЯ ОБЛ         6.29             50.0
# 57                   UNM            МОСКВА         6.99             50.0
# 70                   NaN               NaN         6.99             30.0
# 124                  UNM     ИРКУТСКАЯ ОБЛ         8.49             30.0
# ...                  ...               ...          ...              ...
# 396610               UNM    МОСКОВСКАЯ ОБЛ         8.49             50.0
# 396727               CIV        ОМСКАЯ ОБЛ         6.99             50.0
# 396731               UNM    МОСКОВСКАЯ ОБЛ         6.49             40.0
# 396733               NaN    ТАТАРСТАН РЕСП         4.99             50.0
# 396742               UNM  СВЕРДЛОВСКАЯ ОБЛ         5.76             30.0
#
#         hold_amount  ...               book_end_dttm  book_time_zone_cd  \
# 12            300.0  ...  2024-09-28 06:53:57.360696                  5
# 56            300.0  ...  2024-09-13 07:20:12.761929                  4
# 57            300.0  ...  2024-08-02 08:35:14.438970                  3
# 70            300.0  ...  2024-06-29 09:21:40.328859                  3
# 124           300.0  ...  2024-07-18 03:15:08.255980                  8
# ...             ...  ...                         ...                ...
# 396610        300.0  ...  2024-07-07 08:17:02.960238                  3
# 396727        300.0  ...  2024-06-29 08:55:37.142180                  3
# 396731        300.0  ...  2024-10-01 09:04:37.191565                  3
# 396733        300.0  ...  2024-07-13 08:41:42.622032                  3
# 396742        300.0  ...  2024-09-26 08:28:58.830479                  3
#
#             local_book_start_dttm nominal_price_rub_amt  \
# 12     2024-09-28 08:35:08.384000                143.81
# 56     2024-09-13 08:16:26.593000                 75.16
# 57     2024-08-02 08:34:38.057711                  0.00
# 70     2024-06-29 08:49:42.831294                253.68
# 124    2024-07-18 08:02:39.867790                140.37
# ...                           ...                   ...
# 396610 2024-07-07 08:08:18.354977                126.41
# 396727 2024-06-29 08:47:42.453380                105.92
# 396731 2024-10-01 08:48:18.321000                150.33
# 396733 2024-07-13 08:41:24.496421                  0.00
# 396742 2024-09-26 08:06:12.709000                162.48
#
#        loyalty_accrual_rub_amt  loyalty_accrual_bns_amt  \
# 12                       63.76                      NaN
# 56                        7.52                      NaN
# 57                         NaN                      NaN
# 70                       38.05                      NaN
# 124                      14.04                      NaN
# ...                        ...                      ...
# 396610                   18.96                      NaN
# 396727                   10.59                      NaN
# 396731                   67.06                      NaN
# 396733                     NaN                      NaN
# 396742                   26.37                      NaN
#
#                    travel_time  travel_time_h  average_speed  local_hour_start
# 12      0 days 00:18:48.976696       0.313605      17.038217                 8
# 56      0 days 00:03:46.168929       0.062825      21.412698                 8
# 57      0 days 00:00:36.381259       0.010106       0.000000                 8
# 70      0 days 00:31:57.497565       0.532638       4.506567                 8
# 124     0 days 00:12:28.388190       0.207886      15.187500                 8
# ...                        ...            ...            ...               ...
# 396610  0 days 00:08:44.605261       0.145724       7.363014                 8
# 396727  0 days 00:07:54.688800       0.131858       9.750000                 8
# 396731  0 days 00:16:18.870565       0.271908      26.099265                 8
# 396733  0 days 00:00:18.125611       0.005035       0.000000                 8
# 396742  0 days 00:22:46.121479       0.379478      12.039578                 8
#
# [14796 rows x 24 columns]

# %%
from scipy import stats

# %%
grouped = df.groupby('local_hour_start')

results = {}
for column in df.select_dtypes(include=['float64', 'int64']).columns:
    group_a = grouped.get_group(5)[column]
    group_b = grouped.get_group(8)[column]

    group_a = group_a[group_a.notnull() & group_a.apply(lambda x: isinstance(x, (int, float)))]
    group_b = group_b[group_b.notnull() & group_b.apply(lambda x: isinstance(x, (int, float)))]

    f_stat, p_value = stats.f_oneway(group_a, group_b)
    results[column] = {'f-statistic': f_stat, 'p-value': p_value}

results_df = pd.DataFrame(results).T

results_df = results_df.sort_values(by='p-value')

results_df
# Out:
#                          f-statistic        p-value
# average_speed             761.367924  4.816689e-166
# travel_time_h             491.538900  2.946232e-108
# activation_cost           477.865488  2.564747e-105
# nominal_price_rub_amt     433.070422   1.117309e-95
# loyalty_accrual_rub_amt   318.214502   7.002927e-71
# minute_cost               169.949685   9.097140e-39
# order_rk                   81.141275   2.191406e-19
# party_rk                   44.175595   3.040312e-11
# distance_km                13.422464   2.489484e-04
# book_time_zone_cd          10.375615   1.277922e-03
# hold_amount                 3.431220   6.398214e-02
# loyalty_accrual_bns_amt     2.584928   1.080280e-01
# age                         0.011585   9.142852e-01

# %%
df['created_dttm'] = pd.to_datetime(df['created_dttm'])
df['book_start_dttm'] = pd.to_datetime(df['book_start_dttm'])
df
# Out:
#          order_rk    party_rk gender_cd  age education_level_cd  \
# 0       266071307   761067705         M   40                UGR
# 1       355113920   614049469         F   30                GRD
# 2       347424551   757583701         M   28                UGR
# 3       351562959   541367366         M   24                GRD
# 4       258647149   238473615         M   34                NaN
# ...           ...         ...       ...  ...                ...
# 396744  349109813   755778419         M   18                NaN
# 396745  348829245  1146263947         M   23                NaN
# 396746  273529251  1012601147         M   20                NaN
# 396747  306062051   863877659         M   19                NaN
# 396748  262579355   897372192         M   33                GRD
#
#        marital_status_cd         lvn_state_nm  minute_cost  activation_cost  \
# 0                    DIV        ТЮМЕНСКАЯ ОБЛ         4.99             30.0
# 1                    MAR       РОСТОВСКАЯ ОБЛ         8.49             50.0
# 2                    UNM     СВЕРДЛОВСКАЯ ОБЛ         5.99             30.0
# 3                    UNM               МОСКВА         8.99             50.0
# 4                    NaN               МОСКВА         6.99             50.0
# ...                  ...                  ...          ...              ...
# 396744               NaN     СВЕРДЛОВСКАЯ ОБЛ         6.49             30.0
# 396745               NaN  КАЛИНИНГРАДСКАЯ ОБЛ         8.99             30.0
# 396746               NaN        ТЮМЕНСКАЯ ОБЛ         8.79             50.0
# 396747               NaN      САНКТ-ПЕТЕРБУРГ         7.49             50.0
# 396748               UNM               МОСКВА         8.08             50.0
#
#         hold_amount  ...               book_end_dttm  book_time_zone_cd  \
# 0             300.0  ...  2024-08-07 10:07:59.339524                  5
# 1             300.0  ...  2024-10-17 15:04:19.419607                  3
# 2             300.0  ...  2024-09-19 05:41:50.164372                  5
# 3             300.0  ...  2024-10-04 16:07:31.724918                  3
# 4             300.0  ...  2024-07-10 07:07:48.446462                  3
# ...             ...  ...                         ...                ...
# 396744        300.0  ...  2024-09-25 11:45:41.545313                  5
# 396745        300.0  ...  2024-09-24 20:13:58.592279                  2
# 396746        300.0  ...  2024-09-03 16:28:07.510118                  3
# 396747        300.0  ...  2024-09-12 18:32:22.911827                  3
# 396748        300.0  ...  2024-07-25 07:50:54.825261                  3
#
#             local_book_start_dttm nominal_price_rub_amt  \
# 0      2024-08-07 11:47:29.325252                134.79
# 1      2024-10-17 14:57:24.586000                109.43
# 2      2024-09-19 07:34:59.476000                 71.93
# 3      2024-10-04 16:05:13.162000                 76.97
# 4      2024-07-10 06:57:43.017125                126.89
# ...                           ...                   ...
# 396744 2024-09-25 13:39:46.885000                 68.94
# 396745 2024-09-24 19:05:46.954000                110.91
# 396746 2024-09-03 16:07:45.311487                234.59
# 396747 2024-09-12 18:28:50.401000                 79.96
# 396748 2024-07-25 07:44:10.998103                106.56
#
#        loyalty_accrual_rub_amt  loyalty_accrual_bns_amt  \
# 0                        19.48                      NaN
# 1                        40.30                      NaN
# 2                        10.79                      NaN
# 3                         7.70                      NaN
# 4                        25.38                      NaN
# ...                        ...                      ...
# 396744                    6.89                      NaN
# 396745                   13.09                      NaN
# 396746                  234.59                      NaN
# 396747                   79.96                      NaN
# 396748                   15.66                      NaN
#
#                    travel_time  travel_time_h  average_speed  local_hour_start
# 0       0 days 00:20:30.014272       0.341671      10.789474                11
# 1       0 days 00:06:54.833607       0.115232       9.695652                14
# 2       0 days 00:06:50.688372       0.114080      13.298246                 7
# 3       0 days 00:02:18.562918       0.038490      13.131579                16
# 4       0 days 00:10:05.429337       0.168175      15.488095                 6
# ...                        ...            ...            ...               ...
# 396744  0 days 00:05:54.660313       0.098517      15.707071                13
# 396745  0 days 00:08:11.638279       0.136566      16.576642                19
# 396746  0 days 00:20:22.198631       0.339500       4.162242                16
# 396747  0 days 00:03:32.510827       0.059031      16.983051                18
# 396748  0 days 00:06:43.827158       0.112174       8.160714                 7
#
# [394784 rows x 24 columns]

# %%
df['seconds_difference'] = df['book_start_dttm'] - df['created_dttm']

# %%
df['seconds_difference'] = df['seconds_difference'].dt.total_seconds()

# %%
df
# Out:
#          order_rk    party_rk gender_cd  age education_level_cd  \
# 0       266071307   761067705         M   40                UGR
# 1       355113920   614049469         F   30                GRD
# 2       347424551   757583701         M   28                UGR
# 3       351562959   541367366         M   24                GRD
# 4       258647149   238473615         M   34                NaN
# ...           ...         ...       ...  ...                ...
# 396744  349109813   755778419         M   18                NaN
# 396745  348829245  1146263947         M   23                NaN
# 396746  273529251  1012601147         M   20                NaN
# 396747  306062051   863877659         M   19                NaN
# 396748  262579355   897372192         M   33                GRD
#
#        marital_status_cd         lvn_state_nm  minute_cost  activation_cost  \
# 0                    DIV        ТЮМЕНСКАЯ ОБЛ         4.99             30.0
# 1                    MAR       РОСТОВСКАЯ ОБЛ         8.49             50.0
# 2                    UNM     СВЕРДЛОВСКАЯ ОБЛ         5.99             30.0
# 3                    UNM               МОСКВА         8.99             50.0
# 4                    NaN               МОСКВА         6.99             50.0
# ...                  ...                  ...          ...              ...
# 396744               NaN     СВЕРДЛОВСКАЯ ОБЛ         6.49             30.0
# 396745               NaN  КАЛИНИНГРАДСКАЯ ОБЛ         8.99             30.0
# 396746               NaN        ТЮМЕНСКАЯ ОБЛ         8.79             50.0
# 396747               NaN      САНКТ-ПЕТЕРБУРГ         7.49             50.0
# 396748               UNM               МОСКВА         8.08             50.0
#
#         hold_amount  ... book_time_zone_cd      local_book_start_dttm  \
# 0             300.0  ...                 5 2024-08-07 11:47:29.325252
# 1             300.0  ...                 3 2024-10-17 14:57:24.586000
# 2             300.0  ...                 5 2024-09-19 07:34:59.476000
# 3             300.0  ...                 3 2024-10-04 16:05:13.162000
# 4             300.0  ...                 3 2024-07-10 06:57:43.017125
# ...             ...  ...               ...                        ...
# 396744        300.0  ...                 5 2024-09-25 13:39:46.885000
# 396745        300.0  ...                 2 2024-09-24 19:05:46.954000
# 396746        300.0  ...                 3 2024-09-03 16:07:45.311487
# 396747        300.0  ...                 3 2024-09-12 18:28:50.401000
# 396748        300.0  ...                 3 2024-07-25 07:44:10.998103
#
#        nominal_price_rub_amt loyalty_accrual_rub_amt loyalty_accrual_bns_amt  \
# 0                     134.79                   19.48                     NaN
# 1                     109.43                   40.30                     NaN
# 2                      71.93                   10.79                     NaN
# 3                      76.97                    7.70                     NaN
# 4                     126.89                   25.38                     NaN
# ...                      ...                     ...                     ...
# 396744                 68.94                    6.89                     NaN
# 396745                110.91                   13.09                     NaN
# 396746                234.59                  234.59                     NaN
# 396747                 79.96                   79.96                     NaN
# 396748                106.56                   15.66                     NaN
#
#                    travel_time travel_time_h  average_speed  local_hour_start  \
# 0       0 days 00:20:30.014272      0.341671      10.789474                11
# 1       0 days 00:06:54.833607      0.115232       9.695652                14
# 2       0 days 00:06:50.688372      0.114080      13.298246                 7
# 3       0 days 00:02:18.562918      0.038490      13.131579                16
# 4       0 days 00:10:05.429337      0.168175      15.488095                 6
# ...                        ...           ...            ...               ...
# 396744  0 days 00:05:54.660313      0.098517      15.707071                13
# 396745  0 days 00:08:11.638279      0.136566      16.576642                19
# 396746  0 days 00:20:22.198631      0.339500       4.162242                16
# 396747  0 days 00:03:32.510827      0.059031      16.983051                18
# 396748  0 days 00:06:43.827158      0.112174       8.160714                 7
#
#         seconds_difference
# 0                 4.325252
# 1                 4.586000
# 2               198.476000
# 3                 4.162000
# 4                 3.017125
# ...                    ...
# 396744            4.885000
# 396745            3.954000
# 396746            2.311487
# 396747            2.401000
# 396748            3.998103
#
# [394784 rows x 25 columns]

# %%
grouped = df.groupby('transport_model')

results = {}

for model in grouped.groups:
    group_a = grouped.get_group(model)

    results[model] = {
        'seconds_difference_mean': group_a.seconds_difference.mean(),
        'count': len(group_a.index),
        'age_mean': group_a.age.mean(),
        'age_median': group_a.age.median()
    }

results = pd.DataFrame(results)

results
# sns.barplot(data=results)
# Out:
#                                B1D             E          ES      ES-08S  \
# seconds_difference_mean   4.241752      6.129675    4.552822    5.059018
# count                    36.000000  67602.000000  118.000000  911.000000
# age_mean                 31.666667     30.636179   32.228814   31.091109
# age_median               29.000000     29.000000   31.000000   30.000000
#
#                                ES100        ES200        ES400          LB  \
# seconds_difference_mean     6.047062     5.039690     6.133445    3.988827
# count                    2823.000000  3312.000000  4141.000000  115.000000
# age_mean                   30.416932    30.634662    29.865733   33.660870
# age_median                 29.000000    31.000000    28.000000   32.000000
#
#                              Lucky           MK           Max             SL  \
# seconds_difference_mean   4.863346     4.648866      5.824072       6.178256
# count                    62.000000  1053.000000  69863.000000  239841.000000
# age_mean                 31.370968    31.250712     31.570216      31.834690
# age_median               29.000000    32.000000     31.000000      31.000000
#
#                              Techno  Urban E-Bike
# seconds_difference_mean    5.594878      8.684098
# count                    228.000000   4679.000000
# age_mean                  33.048246     32.017739
# age_median                32.000000     31.000000

# %%
results = {}

for model in grouped.groups:
    for model2 in grouped.groups:
        if model2 == model: continue
        group_a = grouped.get_group(model)
        group_b = grouped.get_group(model2)

        skip = False
        for i in results.keys():
            if model in i.split(':') and model2 in i.split(':'):
                skip = True
                break
        if skip:
            continue
        results[f'{model}:{model2}'] = {}

        f_stat, p_value = stats.f_oneway(group_a.seconds_difference, group_b.seconds_difference)
        results[f'{model}:{model2}']['f-statistic'] = f_stat
        results[f'{model}:{model2}']['p-value'] = p_value

results = pd.DataFrame(results).T

# %%
results[results['p-value'] < 0.05].to_csv('models_anova.csv')
